# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns

def get_file(url):
    result = requests.get(url).json()
    final = pd.DataFrame(result)
    return final

#SETTING API SOURCES
c_summary = get_file("https://api.census.gov/data/2018/abscs?get=NAME,GEO_ID,NAICS2017_LABEL,EMP,PAYANN,RCPPDEMP,YIBSZFI,YIBSZFI_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,FIRMPDEMP&for=state:*&NAICS2017=00&key=626adfc10bf27b262135fc08ea896e98eee867ba")
char_business = get_file("https://api.census.gov/data/2018/abscb?get=NAME,GEO_ID,NAICS2017_LABEL,EMP,PAYANN,RCPPDEMP,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,FIRMPDEMP&for=state:*&NAICS2017=00&BUSCHAR=A1&QDESC=B01&key=626adfc10bf27b262135fc08ea896e98eee867ba")
char_business_owners = get_file("https://api.census.gov/data/2018/abscbo?get=NAME,GEO_ID,NAICS2017_LABEL,OWNER_SEX,OWNER_SEX_LABEL,OWNER_ETH,OWNER_ETH_LABEL,OWNER_RACE,OWNER_RACE_LABEL,OWNER_VET,OWNER_VET_LABEL,OWNPDEMP&for=state:*&OWNCHAR=CG&NAICS2017=00&QDESC=O02&key=626adfc10bf27b262135fc08ea896e98eee867ba")
tech_char = get_file("https://api.census.gov/data/2018/abstcb?get=NAME,GEO_ID,NAICS2017_LABEL,EMP,FACTORS_P,IMPACTWF_P_LABEL,IMPACTWF_U_LABEL,FACTORS_U,PAYANN,MOTUSETECH,MOTUSETECH_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,TECHUSE,TECHUSE_LABEL,FIRMPDEMP&for=state:*&NAICS2017=00&key=626adfc10bf27b262135fc08ea896e98eee867ba")

#REPLACING COLUMNS WITH 1ST ROW NAMES
c_summary.columns = c_summary.iloc[0]
char_business.columns = char_business.iloc[0]
char_business_owners.columns = char_business_owners.iloc[0]
tech_char.columns = tech_char.iloc[0]

#REMOVING UNESSECARY ROW AFTER RENAMING COLUMNS
c_summary = c_summary.drop(c_summary.index[0])
char_business = char_business.drop(char_business.index[0])
char_business_owners = char_business_owners.drop(char_business_owners.index[0])
tech_char = tech_char.drop(tech_char.index[0])

# %%
c_summary.columns
# Out:
# Index(['NAME', 'GEO_ID', 'NAICS2017_LABEL', 'EMP', 'PAYANN', 'RCPPDEMP',
#        'YIBSZFI', 'YIBSZFI_LABEL', 'SEX', 'SEX_LABEL', 'ETH_GROUP',
#        'ETH_GROUP_LABEL', 'RACE_GROUP', 'RACE_GROUP_LABEL', 'VET_GROUP',
#        'VET_GROUP_LABEL', 'FIRMPDEMP', 'NAICS2017', 'state'],
#       dtype='object', name=0)

# %%
c_summary.EMP.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1            284
# 2              0
# 3              0
# 4              0
# 5            975
#           ...
# 36135     622372
# 36136    1243711
# 36137      57503
# 36138      65917
# 36139      80338
# Name: EMP, Length: 36139, dtype: object>

# %%
char_business.columns
# Out:
# Index(['NAME', 'GEO_ID', 'NAICS2017_LABEL', 'EMP', 'PAYANN', 'RCPPDEMP', 'SEX',
#        'SEX_LABEL', 'ETH_GROUP', 'ETH_GROUP_LABEL', 'RACE_GROUP',
#        'RACE_GROUP_LABEL', 'VET_GROUP', 'VET_GROUP_LABEL', 'FIRMPDEMP',
#        'NAICS2017', 'BUSCHAR', 'QDESC', 'state'],
#       dtype='object', name=0)

# %%
char_business_owners.columns
# Out:
# Index(['NAME', 'GEO_ID', 'NAICS2017_LABEL', 'OWNER_SEX', 'OWNER_SEX_LABEL',
#        'OWNER_ETH', 'OWNER_ETH_LABEL', 'OWNER_RACE', 'OWNER_RACE_LABEL',
#        'OWNER_VET', 'OWNER_VET_LABEL', 'OWNPDEMP', 'OWNCHAR', 'NAICS2017',
#        'QDESC', 'state'],
#       dtype='object', name=0)

# %%
tech_char.columns
# Out:
# Index(['NAME', 'GEO_ID', 'NAICS2017_LABEL', 'EMP', 'FACTORS_P',
#        'IMPACTWF_P_LABEL', 'IMPACTWF_U_LABEL', 'FACTORS_U', 'PAYANN',
#        'MOTUSETECH', 'MOTUSETECH_LABEL', 'SEX', 'SEX_LABEL', 'ETH_GROUP',
#        'ETH_GROUP_LABEL', 'RACE_GROUP', 'RACE_GROUP_LABEL', 'VET_GROUP',
#        'VET_GROUP_LABEL', 'TECHUSE', 'TECHUSE_LABEL', 'FIRMPDEMP', 'NAICS2017',
#        'state'],
#       dtype='object', name=0)

# %%
c_summary
# Out:
# 0             NAME       GEO_ID        NAICS2017_LABEL      EMP    PAYANN  \
# 1      Mississippi  0400000US28  Total for all sectors      284      8839
# 2      Mississippi  0400000US28  Total for all sectors        0         0
# 3      Mississippi  0400000US28  Total for all sectors        0         0
# 4      Mississippi  0400000US28  Total for all sectors        0         0
# 5      Mississippi  0400000US28  Total for all sectors      975     25729
# ...            ...          ...                    ...      ...       ...
# 36135    Minnesota  0400000US27  Total for all sectors   622372  30754306
# 36136    Minnesota  0400000US27  Total for all sectors  1243711  52997220
# 36137    Minnesota  0400000US27  Total for all sectors    57503   2232338
# 36138    Minnesota  0400000US27  Total for all sectors    65917   2152950
# 36139    Minnesota  0400000US27  Total for all sectors    80338   2905169
#
# 0     RCPPDEMP YIBSZFI                             YIBSZFI_LABEL  SEX  \
# 1            0     311  Firms with less than 2 years in business  001
# 2            0     318       Firms with 2 to 3 years in business  001
# 3            0     319       Firms with 4 to 5 years in business  001
# 4            0     321      Firms with 6 to 10 years in business  001
# 5            0     322     Firms with 11 to 15 years in business  001
# ...        ...     ...                                       ...  ...
# 36135        0     323   Firms with 16 or more years in business  001
# 36136        0     001                                 All firms  096
# 36137        0     311  Firms with less than 2 years in business  096
# 36138        0     318       Firms with 2 to 3 years in business  096
# 36139        0     319       Firms with 4 to 5 years in business  096
#
# 0         SEX_LABEL ETH_GROUP ETH_GROUP_LABEL RACE_GROUP RACE_GROUP_LABEL  \
# 1             Total       029    Non-Hispanic         00            Total
# 2             Total       029    Non-Hispanic         00            Total
# 3             Total       029    Non-Hispanic         00            Total
# 4             Total       029    Non-Hispanic         00            Total
# 5             Total       029    Non-Hispanic         00            Total
# ...             ...       ...             ...        ...              ...
# 36135         Total       001           Total         92      Nonminority
# 36136  Classifiable       096    Classifiable         96     Classifiable
# 36137  Classifiable       096    Classifiable         96     Classifiable
# 36138  Classifiable       096    Classifiable         96     Classifiable
# 36139  Classifiable       096    Classifiable         96     Classifiable
#
# 0     VET_GROUP             VET_GROUP_LABEL FIRMPDEMP NAICS2017 state
# 1           003  Equally veteran/nonveteran        97        00    28
# 2           003  Equally veteran/nonveteran         0        00    28
# 3           003  Equally veteran/nonveteran         0        00    28
# 4           003  Equally veteran/nonveteran         0        00    28
# 5           003  Equally veteran/nonveteran       116        00    28
# ...         ...                         ...       ...       ...   ...
# 36135       004                  Nonveteran     32620        00    27
# 36136       096                Classifiable    105997        00    27
# 36137       096                Classifiable     13338        00    27
# 36138       096                Classifiable     11394        00    27
# 36139       096                Classifiable      9360        00    27
#
# [36139 rows x 19 columns]

# %%
# c_summary.info()
int_c_summary = c_summary.EMP.astype(int)
most_employees = int_c_summary.nlargest(20)
type(most_employees)
most_employees
most_employees_index = most_employees.axes
most_employees_index
# Out:
# [Int64Index([21663, 13321, 21669, 25372,  5925, 22457, 13327, 22464, 22487,
#              22306, 22480, 22363, 25378, 21884,  5931, 22373, 10419, 28334,
#              22071, 13746],
#             dtype='int64')]

# %%
most_employees_values = most_employees.values
most_employees_values
# Out:
# array([14991308, 10562214, 10546786,  8441008,  8073389,  7741776,
#         7578314,  7249533,  7220766,  6964445])

# %%
for axes in most_employees_index:
    print(c_summary.iloc[axes].NAME)
# Out:
# 21664      California
# 13322           Texas
# 21670      California
# 25373         Florida
# 5926         New York
# 22458      California
# 13328           Texas
# 22465      California
# 22488      California
# 22307      California
# 22481      California
# 22364      California
# 25379         Florida
# 21885      California
# 5932         New York
# 22374      California
# 10420    Pennsylvania
# 28335        Illinois
# 22072      California
# 13747           Texas
# Name: NAME, dtype: object

# %%
char_business
# Out:
# 0                   NAME       GEO_ID        NAICS2017_LABEL       EMP  \
# 1            Mississippi  0400000US28  Total for all sectors    920447
# 2               Missouri  0400000US29  Total for all sectors   2464500
# 3                Montana  0400000US30  Total for all sectors    361600
# 4               Nebraska  0400000US31  Total for all sectors    855009
# 5                 Nevada  0400000US32  Total for all sectors   1240230
# 6          New Hampshire  0400000US33  Total for all sectors    584769
# 7             New Jersey  0400000US34  Total for all sectors   3736734
# 8             New Mexico  0400000US35  Total for all sectors    584145
# 9               New York  0400000US36  Total for all sectors   8073389
# 10        North Carolina  0400000US37  Total for all sectors   3679286
# 11          North Dakota  0400000US38  Total for all sectors    333115
# 12                  Ohio  0400000US39  Total for all sectors   4817903
# 13              Oklahoma  0400000US40  Total for all sectors   1344715
# 14                Oregon  0400000US41  Total for all sectors   1617123
# 15          Pennsylvania  0400000US42  Total for all sectors   5556497
# 16          Rhode Island  0400000US44  Total for all sectors    445167
# 17        South Carolina  0400000US45  Total for all sectors   1825775
# 18          South Dakota  0400000US46  Total for all sectors    317810
# 19             Tennessee  0400000US47  Total for all sectors   2635392
# 20                 Texas  0400000US48  Total for all sectors  10562214
# 21               Vermont  0400000US50  Total for all sectors    241404
# 22                  Utah  0400000US49  Total for all sectors   1273415
# 23              Virginia  0400000US51  Total for all sectors   3293668
# 24            Washington  0400000US53  Total for all sectors   2752850
# 25         West Virginia  0400000US54  Total for all sectors    529733
# 26             Wisconsin  0400000US55  Total for all sectors   2595886
# 27               Wyoming  0400000US56  Total for all sectors    210845
# 28               Alabama  0400000US01  Total for all sectors   1630135
# 29                Alaska  0400000US02  Total for all sectors    258119
# 30               Arizona  0400000US04  Total for all sectors   2525257
# 31              Arkansas  0400000US05  Total for all sectors   1011278
# 32            California  0400000US06  Total for all sectors  14991308
# 33              Colorado  0400000US08  Total for all sectors   2434968
# 34              Delaware  0400000US10  Total for all sectors    406179
# 35  District of Columbia  0400000US11  Total for all sectors    455652
# 36                 Idaho  0400000US16  Total for all sectors    598348
# 37           Connecticut  0400000US09  Total for all sectors   1476827
# 38               Florida  0400000US12  Total for all sectors   8441008
# 39               Georgia  0400000US13  Total for all sectors   3805183
# 40                Hawaii  0400000US15  Total for all sectors    505452
# 41              Illinois  0400000US17  Total for all sectors   5474518
# 42               Indiana  0400000US18  Total for all sectors   2747840
# 43                  Iowa  0400000US19  Total for all sectors   1341265
# 44                Kansas  0400000US20  Total for all sectors   1260598
# 45              Kentucky  0400000US21  Total for all sectors   1609352
# 46             Louisiana  0400000US22  Total for all sectors   1671852
# 47                 Maine  0400000US23  Total for all sectors    498963
# 48              Maryland  0400000US24  Total for all sectors   2276097
# 49         Massachusetts  0400000US25  Total for all sectors   3311909
# 50              Michigan  0400000US26  Total for all sectors   3937663
# 51             Minnesota  0400000US27  Total for all sectors   2673014
#
# 0      PAYANN RCPPDEMP  SEX SEX_LABEL ETH_GROUP ETH_GROUP_LABEL RACE_GROUP  \
# 1    34137231        0  001     Total       001           Total         00
# 2   116172182        0  001     Total       001           Total         00
# 3    14060286        0  001     Total       001           Total         00
# 4    38441262        0  001     Total       001           Total         00
# 5    55634075        0  001     Total       001           Total         00
# 6    30156054        0  001     Total       001           Total         00
# 7   229676168        0  001     Total       001           Total         00
# 8    24658546        0  001     Total       001           Total         00
# 9   546738617        0  001     Total       001           Total         00
# 10  176807199        0  001     Total       001           Total         00
# 11   17183698        0  001     Total       001           Total         00
# 12  235298311        0  001     Total       001           Total         00
# 13   59763886        0  001     Total       001           Total         00
# 14   80842532        0  001     Total       001           Total         00
# 15  279958625        0  001     Total       001           Total         00
# 16   23624401        0  001     Total       001           Total         00
# 17   75694478        0  001     Total       001           Total         00
# 18   13331371        0  001     Total       001           Total         00
# 19  124839833        0  001     Total       001           Total         00
# 20  576612381        0  001     Total       001           Total         00
# 21   10391634        0  001     Total       001           Total         00
# 22   58271743        0  001     Total       001           Total         00
# 23  184731636        0  001     Total       001           Total         00
# 24  173854547        0  001     Total       001           Total         00
# 25   21776423        0  001     Total       001           Total         00
# 26  129965242        0  001     Total       001           Total         00
# 27    9624017        0  001     Total       001           Total         00
# 28   73502277        0  001     Total       001           Total         00
# 29   15344471        0  001     Total       001           Total         00
# 30  120495466        0  001     Total       001           Total         00
# 31   42192293        0  001     Total       001           Total         00
# 32  987704916        0  001     Total       001           Total         00
# 33  134369487        0  001     Total       001           Total         00
# 34   23826058        0  001     Total       001           Total         00
# 35   37728542        0  001     Total       001           Total         00
# 36   23195317        0  001     Total       001           Total         00
# 37   98448097        0  001     Total       001           Total         00
# 38  388187677        0  001     Total       001           Total         00
# 39  196353564        0  001     Total       001           Total         00
# 40   23429423        0  001     Total       001           Total         00
# 41  321222632        0  001     Total       001           Total         00
# 42  126645780        0  001     Total       001           Total         00
# 43   61255559        0  001     Total       001           Total         00
# 44   54906128        0  001     Total       001           Total         00
# 45   70349726        0  001     Total       001           Total         00
# 46   77549488        0  001     Total       001           Total         00
# 47   21418377        0  001     Total       001           Total         00
# 48  127674716        0  001     Total       001           Total         00
# 49  227796997        0  001     Total       001           Total         00
# 50  194684377        0  001     Total       001           Total         00
# 51  146712564        0  001     Total       001           Total         00
#
# 0  RACE_GROUP_LABEL VET_GROUP VET_GROUP_LABEL FIRMPDEMP NAICS2017 BUSCHAR  \
# 1             Total       001           Total     40856        00      A1
# 2             Total       001           Total    106753        00      A1
# 3             Total       001           Total     31661        00      A1
# 4             Total       001           Total     43189        00      A1
# 5             Total       001           Total     51758        00      A1
# 6             Total       001           Total     28969        00      A1
# 7             Total       001           Total    187243        00      A1
# 8             Total       001           Total     32197        00      A1
# 9             Total       001           Total    446155        00      A1
# 10            Total       001           Total    167837        00      A1
# 11            Total       001           Total     19844        00      A1
# 12            Total       001           Total    170951        00      A1
# 13            Total       001           Total     68623        00      A1
# 14            Total       001           Total     91493        00      A1
# 15            Total       001           Total    214291        00      A1
# 16            Total       001           Total     22900        00      A1
# 17            Total       001           Total     78512        00      A1
# 18            Total       001           Total     21641        00      A1
# 19            Total       001           Total     91799        00      A1
# 20            Total       001           Total    425425        00      A1
# 21            Total       001           Total     16471        00      A1
# 22            Total       001           Total     66525        00      A1
# 23            Total       001           Total    143980        00      A1
# 24            Total       001           Total    148872        00      A1
# 25            Total       001           Total     23369        00      A1
# 26            Total       001           Total    103744        00      A1
# 27            Total       001           Total     17113        00      A1
# 28            Total       001           Total     67504        00      A1
# 29            Total       001           Total     15698        00      A1
# 30            Total       001           Total    107152        00      A1
# 31            Total       001           Total     47250        00      A1
# 32            Total       001           Total    738370        00      A1
# 33            Total       001           Total    137165        00      A1
# 34            Total       001           Total     19663        00      A1
# 35            Total       001           Total     15418        00      A1
# 36            Total       001           Total     39080        00      A1
# 37            Total       001           Total     66783        00      A1
# 38            Total       001           Total    447363        00      A1
# 39            Total       001           Total    174985        00      A1
# 40            Total       001           Total     23687        00      A1
# 41            Total       001           Total    245445        00      A1
# 42            Total       001           Total    102882        00      A1
# 43            Total       001           Total     60610        00      A1
# 44            Total       001           Total     54984        00      A1
# 45            Total       001           Total     63236        00      A1
# 46            Total       001           Total     76877        00      A1
# 47            Total       001           Total     32044        00      A1
# 48            Total       001           Total    104197        00      A1
# 49            Total       001           Total    137196        00      A1
# 50            Total       001           Total    163850        00      A1
# 51            Total       001           Total    113774        00      A1
#
# 0  QDESC state
# 1    B01    28
# 2    B01    29
# 3    B01    30
# 4    B01    31
# 5    B01    32
# 6    B01    33
# 7    B01    34
# 8    B01    35
# 9    B01    36
# 10   B01    37
# 11   B01    38
# 12   B01    39
# 13   B01    40
# 14   B01    41
# 15   B01    42
# 16   B01    44
# 17   B01    45
# 18   B01    46
# 19   B01    47
# 20   B01    48
# 21   B01    50
# 22   B01    49
# 23   B01    51
# 24   B01    53
# 25   B01    54
# 26   B01    55
# 27   B01    56
# 28   B01    01
# 29   B01    02
# 30   B01    04
# 31   B01    05
# 32   B01    06
# 33   B01    08
# 34   B01    10
# 35   B01    11
# 36   B01    16
# 37   B01    09
# 38   B01    12
# 39   B01    13
# 40   B01    15
# 41   B01    17
# 42   B01    18
# 43   B01    19
# 44   B01    20
# 45   B01    21
# 46   B01    22
# 47   B01    23
# 48   B01    24
# 49   B01    25
# 50   B01    26
# 51   B01    27

# %%
char_business_owners
# Out:
# 0                   NAME       GEO_ID        NAICS2017_LABEL OWNER_SEX  \
# 1            Mississippi  0400000US28  Total for all sectors       001
# 2               Missouri  0400000US29  Total for all sectors       001
# 3                Montana  0400000US30  Total for all sectors       001
# 4               Nebraska  0400000US31  Total for all sectors       001
# 5                 Nevada  0400000US32  Total for all sectors       001
# 6          New Hampshire  0400000US33  Total for all sectors       001
# 7             New Jersey  0400000US34  Total for all sectors       001
# 8             New Mexico  0400000US35  Total for all sectors       001
# 9               New York  0400000US36  Total for all sectors       001
# 10        North Carolina  0400000US37  Total for all sectors       001
# 11          North Dakota  0400000US38  Total for all sectors       001
# 12                  Ohio  0400000US39  Total for all sectors       001
# 13              Oklahoma  0400000US40  Total for all sectors       001
# 14                Oregon  0400000US41  Total for all sectors       001
# 15          Pennsylvania  0400000US42  Total for all sectors       001
# 16          Rhode Island  0400000US44  Total for all sectors       001
# 17        South Carolina  0400000US45  Total for all sectors       001
# 18          South Dakota  0400000US46  Total for all sectors       001
# 19             Tennessee  0400000US47  Total for all sectors       001
# 20                 Texas  0400000US48  Total for all sectors       001
# 21               Vermont  0400000US50  Total for all sectors       001
# 22                  Utah  0400000US49  Total for all sectors       001
# 23              Virginia  0400000US51  Total for all sectors       001
# 24            Washington  0400000US53  Total for all sectors       001
# 25         West Virginia  0400000US54  Total for all sectors       001
# 26             Wisconsin  0400000US55  Total for all sectors       001
# 27               Wyoming  0400000US56  Total for all sectors       001
# 28               Alabama  0400000US01  Total for all sectors       001
# 29                Alaska  0400000US02  Total for all sectors       001
# 30               Arizona  0400000US04  Total for all sectors       001
# 31              Arkansas  0400000US05  Total for all sectors       001
# 32            California  0400000US06  Total for all sectors       001
# 33              Colorado  0400000US08  Total for all sectors       001
# 34              Delaware  0400000US10  Total for all sectors       001
# 35  District of Columbia  0400000US11  Total for all sectors       001
# 36                 Idaho  0400000US16  Total for all sectors       001
# 37           Connecticut  0400000US09  Total for all sectors       001
# 38               Florida  0400000US12  Total for all sectors       001
# 39               Georgia  0400000US13  Total for all sectors       001
# 40                Hawaii  0400000US15  Total for all sectors       001
# 41              Illinois  0400000US17  Total for all sectors       001
# 42               Indiana  0400000US18  Total for all sectors       001
# 43                  Iowa  0400000US19  Total for all sectors       001
# 44                Kansas  0400000US20  Total for all sectors       001
# 45              Kentucky  0400000US21  Total for all sectors       001
# 46             Louisiana  0400000US22  Total for all sectors       001
# 47                 Maine  0400000US23  Total for all sectors       001
# 48              Maryland  0400000US24  Total for all sectors       001
# 49         Massachusetts  0400000US25  Total for all sectors       001
# 50              Michigan  0400000US26  Total for all sectors       001
# 51             Minnesota  0400000US27  Total for all sectors       001
#
# 0                  OWNER_SEX_LABEL OWNER_ETH                 OWNER_ETH_LABEL  \
# 1   All owners of respondent firms       001  All owners of respondent firms
# 2   All owners of respondent firms       001  All owners of respondent firms
# 3   All owners of respondent firms       001  All owners of respondent firms
# 4   All owners of respondent firms       001  All owners of respondent firms
# 5   All owners of respondent firms       001  All owners of respondent firms
# 6   All owners of respondent firms       001  All owners of respondent firms
# 7   All owners of respondent firms       001  All owners of respondent firms
# 8   All owners of respondent firms       001  All owners of respondent firms
# 9   All owners of respondent firms       001  All owners of respondent firms
# 10  All owners of respondent firms       001  All owners of respondent firms
# 11  All owners of respondent firms       001  All owners of respondent firms
# 12  All owners of respondent firms       001  All owners of respondent firms
# 13  All owners of respondent firms       001  All owners of respondent firms
# 14  All owners of respondent firms       001  All owners of respondent firms
# 15  All owners of respondent firms       001  All owners of respondent firms
# 16  All owners of respondent firms       001  All owners of respondent firms
# 17  All owners of respondent firms       001  All owners of respondent firms
# 18  All owners of respondent firms       001  All owners of respondent firms
# 19  All owners of respondent firms       001  All owners of respondent firms
# 20  All owners of respondent firms       001  All owners of respondent firms
# 21  All owners of respondent firms       001  All owners of respondent firms
# 22  All owners of respondent firms       001  All owners of respondent firms
# 23  All owners of respondent firms       001  All owners of respondent firms
# 24  All owners of respondent firms       001  All owners of respondent firms
# 25  All owners of respondent firms       001  All owners of respondent firms
# 26  All owners of respondent firms       001  All owners of respondent firms
# 27  All owners of respondent firms       001  All owners of respondent firms
# 28  All owners of respondent firms       001  All owners of respondent firms
# 29  All owners of respondent firms       001  All owners of respondent firms
# 30  All owners of respondent firms       001  All owners of respondent firms
# 31  All owners of respondent firms       001  All owners of respondent firms
# 32  All owners of respondent firms       001  All owners of respondent firms
# 33  All owners of respondent firms       001  All owners of respondent firms
# 34  All owners of respondent firms       001  All owners of respondent firms
# 35  All owners of respondent firms       001  All owners of respondent firms
# 36  All owners of respondent firms       001  All owners of respondent firms
# 37  All owners of respondent firms       001  All owners of respondent firms
# 38  All owners of respondent firms       001  All owners of respondent firms
# 39  All owners of respondent firms       001  All owners of respondent firms
# 40  All owners of respondent firms       001  All owners of respondent firms
# 41  All owners of respondent firms       001  All owners of respondent firms
# 42  All owners of respondent firms       001  All owners of respondent firms
# 43  All owners of respondent firms       001  All owners of respondent firms
# 44  All owners of respondent firms       001  All owners of respondent firms
# 45  All owners of respondent firms       001  All owners of respondent firms
# 46  All owners of respondent firms       001  All owners of respondent firms
# 47  All owners of respondent firms       001  All owners of respondent firms
# 48  All owners of respondent firms       001  All owners of respondent firms
# 49  All owners of respondent firms       001  All owners of respondent firms
# 50  All owners of respondent firms       001  All owners of respondent firms
# 51  All owners of respondent firms       001  All owners of respondent firms
#
# 0  OWNER_RACE                OWNER_RACE_LABEL OWNER_VET  \
# 1          00  All owners of respondent firms       001
# 2          00  All owners of respondent firms       001
# 3          00  All owners of respondent firms       001
# 4          00  All owners of respondent firms       001
# 5          00  All owners of respondent firms       001
# 6          00  All owners of respondent firms       001
# 7          00  All owners of respondent firms       001
# 8          00  All owners of respondent firms       001
# 9          00  All owners of respondent firms       001
# 10         00  All owners of respondent firms       001
# 11         00  All owners of respondent firms       001
# 12         00  All owners of respondent firms       001
# 13         00  All owners of respondent firms       001
# 14         00  All owners of respondent firms       001
# 15         00  All owners of respondent firms       001
# 16         00  All owners of respondent firms       001
# 17         00  All owners of respondent firms       001
# 18         00  All owners of respondent firms       001
# 19         00  All owners of respondent firms       001
# 20         00  All owners of respondent firms       001
# 21         00  All owners of respondent firms       001
# 22         00  All owners of respondent firms       001
# 23         00  All owners of respondent firms       001
# 24         00  All owners of respondent firms       001
# 25         00  All owners of respondent firms       001
# 26         00  All owners of respondent firms       001
# 27         00  All owners of respondent firms       001
# 28         00  All owners of respondent firms       001
# 29         00  All owners of respondent firms       001
# 30         00  All owners of respondent firms       001
# 31         00  All owners of respondent firms       001
# 32         00  All owners of respondent firms       001
# 33         00  All owners of respondent firms       001
# 34         00  All owners of respondent firms       001
# 35         00  All owners of respondent firms       001
# 36         00  All owners of respondent firms       001
# 37         00  All owners of respondent firms       001
# 38         00  All owners of respondent firms       001
# 39         00  All owners of respondent firms       001
# 40         00  All owners of respondent firms       001
# 41         00  All owners of respondent firms       001
# 42         00  All owners of respondent firms       001
# 43         00  All owners of respondent firms       001
# 44         00  All owners of respondent firms       001
# 45         00  All owners of respondent firms       001
# 46         00  All owners of respondent firms       001
# 47         00  All owners of respondent firms       001
# 48         00  All owners of respondent firms       001
# 49         00  All owners of respondent firms       001
# 50         00  All owners of respondent firms       001
# 51         00  All owners of respondent firms       001
#
# 0                  OWNER_VET_LABEL OWNPDEMP OWNCHAR NAICS2017 QDESC state
# 1   All owners of respondent firms     1158      CG        00   O02    28
# 2   All owners of respondent firms     3564      CG        00   O02    29
# 3   All owners of respondent firms      748      CG        00   O02    30
# 4   All owners of respondent firms     1612      CG        00   O02    31
# 5   All owners of respondent firms      572      CG        00   O02    32
# 6   All owners of respondent firms      661      CG        00   O02    33
# 7   All owners of respondent firms     5324      CG        00   O02    34
# 8   All owners of respondent firms      788      CG        00   O02    35
# 9   All owners of respondent firms     8918      CG        00   O02    36
# 10  All owners of respondent firms     4256      CG        00   O02    37
# 11  All owners of respondent firms      875      CG        00   O02    38
# 12  All owners of respondent firms     6829      CG        00   O02    39
# 13  All owners of respondent firms     2276      CG        00   O02    40
# 14  All owners of respondent firms     2577      CG        00   O02    41
# 15  All owners of respondent firms     7344      CG        00   O02    42
# 16  All owners of respondent firms      312      CG        00   O02    44
# 17  All owners of respondent firms     2111      CG        00   O02    45
# 18  All owners of respondent firms      490      CG        00   O02    46
# 19  All owners of respondent firms     3184      CG        00   O02    47
# 20  All owners of respondent firms     8943      CG        00   O02    48
# 21  All owners of respondent firms      749      CG        00   O02    50
# 22  All owners of respondent firms     1369      CG        00   O02    49
# 23  All owners of respondent firms     3498      CG        00   O02    51
# 24  All owners of respondent firms     3404      CG        00   O02    53
# 25  All owners of respondent firms     1057      CG        00   O02    54
# 26  All owners of respondent firms     4236      CG        00   O02    55
# 27  All owners of respondent firms      325      CG        00   O02    56
# 28  All owners of respondent firms     2042      CG        00   O02    01
# 29  All owners of respondent firms      306      CG        00   O02    02
# 30  All owners of respondent firms     1509      CG        00   O02    04
# 31  All owners of respondent firms     1828      CG        00   O02    05
# 32  All owners of respondent firms    17719      CG        00   O02    06
# 33  All owners of respondent firms     2765      CG        00   O02    08
# 34  All owners of respondent firms      289      CG        00   O02    10
# 35  All owners of respondent firms      307      CG        00   O02    11
# 36  All owners of respondent firms     1220      CG        00   O02    16
# 37  All owners of respondent firms     1544      CG        00   O02    09
# 38  All owners of respondent firms     6716      CG        00   O02    12
# 39  All owners of respondent firms     3168      CG        00   O02    13
# 40  All owners of respondent firms      651      CG        00   O02    15
# 41  All owners of respondent firms     6507      CG        00   O02    17
# 42  All owners of respondent firms     4142      CG        00   O02    18
# 43  All owners of respondent firms     2830      CG        00   O02    19
# 44  All owners of respondent firms     2458      CG        00   O02    20
# 45  All owners of respondent firms     2398      CG        00   O02    21
# 46  All owners of respondent firms     2433      CG        00   O02    22
# 47  All owners of respondent firms      882      CG        00   O02    23
# 48  All owners of respondent firms     2325      CG        00   O02    24
# 49  All owners of respondent firms     3655      CG        00   O02    25
# 50  All owners of respondent firms     5063      CG        00   O02    26
# 51  All owners of respondent firms     3210      CG        00   O02    27

# %%
tech_char
# Out:
# 0        NAME       GEO_ID        NAICS2017_LABEL      EMP FACTORS_P  \
# 1     Alabama  0400000US01  Total for all sectors   786873        00
# 2     Alabama  0400000US01  Total for all sectors  1420465        00
# 3     Alabama  0400000US01  Total for all sectors   427265        00
# 4     Alabama  0400000US01  Total for all sectors    13853        00
# 5     Alabama  0400000US01  Total for all sectors   119682        00
# ...       ...          ...                    ...      ...       ...
# 9431  Wyoming  0400000US56  Total for all sectors     4026        00
# 9432  Wyoming  0400000US56  Total for all sectors     7175        00
# 9433  Wyoming  0400000US56  Total for all sectors    14150        00
# 9434  Wyoming  0400000US56  Total for all sectors    17951        00
# 9435  Wyoming  0400000US56  Total for all sectors   184084        00
#
# 0    IMPACTWF_P_LABEL IMPACTWF_U_LABEL FACTORS_U    PAYANN MOTUSETECH  ...  \
# 1           All firms        All firms        00  36136501         00  ...
# 2           All firms        All firms        00  65324725         00  ...
# 3           All firms        All firms        00  17464089         00  ...
# 4           All firms        All firms        00    899625         00  ...
# 5           All firms        All firms        00   5254931         00  ...
# ...               ...              ...       ...       ...        ...  ...
# 9431        All firms        All firms        00    311778         00  ...
# 9432        All firms        All firms        00    258365         00  ...
# 9433        All firms        All firms        00    783236         00  ...
# 9434        All firms        All firms        00   1118387         00  ...
# 9435        All firms        All firms        00   8684515         00  ...
#
# 0    ETH_GROUP_LABEL RACE_GROUP RACE_GROUP_LABEL VET_GROUP VET_GROUP_LABEL  \
# 1              Total         00            Total       001           Total
# 2              Total         00            Total       001           Total
# 3              Total         00            Total       001           Total
# 4              Total         00            Total       001           Total
# 5              Total         00            Total       001           Total
# ...              ...        ...              ...       ...             ...
# 9431           Total         00            Total       001           Total
# 9432           Total         00            Total       001           Total
# 9433           Total         00            Total       001           Total
# 9434           Total         00            Total       001           Total
# 9435           Total         00            Total       001           Total
#
# 0      TECHUSE                                      TECHUSE_LABEL FIRMPDEMP  \
# 1     T2E03B99                             Cloud-Based: Total use     17448
# 2     T2E03BA9                       Cloud-Based: Total Reporting     58136
# 3     T3E03B01                  Specialized Software: Did not use     30912
# 4     T3E03B02  Specialized Software: Tested, but did not use ...       253
# 5     T3E03B03                      Specialized Software: Low use      4191
# ...        ...                                                ...       ...
# 9431  T4E03B04                             Robotics: Moderate use        65
# 9432  T4E03B05                                 Robotics: High use        22
# 9433  T4E03B06                               Robotics: Don't know       528
# 9434  T4E03B99                                Robotics: Total use       274
# 9435  T4E03BA9                          Robotics: Total Reporting     14423
#
# 0    NAICS2017 state
# 1           00    01
# 2           00    01
# 3           00    01
# 4           00    01
# 5           00    01
# ...        ...   ...
# 9431        00    56
# 9432        00    56
# 9433        00    56
# 9434        00    56
# 9435        00    56
#
# [9435 rows x 24 columns]
